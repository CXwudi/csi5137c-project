# %%
# Install pip packages from requirements.txt into this current Jupyter kernel
import sys
# !{sys.executable} -m pip install -r requirements.txt
import pandas as pd

# %% [markdown]
# ## Import

# %%
raw_dataset = pd.read_csv('../data/authors_dataset.csv')
raw_dataset

# %% [markdown]
# ## Preprocessing

# %%
from modules.preprocessing import preprocessing_df
preprocessed_dataset = preprocessing_df(raw_dataset)
preprocessed_dataset
# Out:
# [nltk_data] Downloading package stopwords to /home/cxwudi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/cxwudi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/cxwudi/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/cxwudi/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/cxwudi/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#                      date      id  no.Comments  score  upvote ratio  ups  \
# 0     2019-08-28 14:14:32  cwle38           48    637          0.98  637
# 1     2019-07-03 19:02:44  c8s3x2           15    448          0.97  448
# ...

# %% [markdown]
# **WARNING**: The following code will take 6 minutes to run, even with AMD Ryzen 9 5950x.

# %%
from modules.preprocessing import proprocessing_text
tokenized_dataset = proprocessing_text(preprocessed_dataset)
tokenized_dataset
# Out:
#                      date      id  no.Comments  score  upvote ratio  ups  \
# 0     2019-08-28 14:14:32  cwle38           48    637          0.98  637
# 1     2019-07-03 19:02:44  c8s3x2           15    448          0.97  448
# 2     2020-01-06 15:30:11  ekvldh           51    424          0.96  424
# 3     2020-03-27 14:29:08  fpxv8h           24    360          0.94  360
# 4     2020-02-26 18:00:17  f9x942           60    300          0.98  300
# ...                   ...     ...          ...    ...           ...  ...
# 1909         2/9/20 18:09  f1cfwr            3      4          1.00    4
# 1910         2/3/20 20:41  eydk1i            4      3          0.81    3
# 1911       12/20/19 21:21  edg9ol            4      5          1.00    5
# 1912       12/10/19 16:25  e8ssxt            2      3          0.81    3
# 1913         3/29/20 5:05  fr0bua            1      3          1.00    3
#
#       downs                                     title  \
# ...

# %% [markdown]
# ## To trainable dataset
#
# apply Bag of Word with TF-IDF instead of word count
#
# we will have 3 separate BoW, each for "title", "selftext", and "comments"
